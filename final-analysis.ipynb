# %% [markdown]
# # Univariate Analyse des Bank Marketing Datasets
# Dieses Notebook führt eine univariate Analyse der Daten aus der bank-full.csv durch.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings

plt.style.use('seaborn-v0_8')
sns.set_palette('husl')
plt.rcParams['figure.figsize'] = (10, 6)
warnings.filterwarnings('ignore')

# %%
raw_data = pd.read_csv('bank-full.csv', sep=';')

print(raw_data.shape)
print(raw_data.columns.tolist())
display(raw_data.describe())
display(raw_data.describe(include=['object']))
# Out:
# (45211, 17)
# ['age', 'job', 'marital', 'education', 'default', 'balance', 'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'y']
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# ...

# %% [markdown]
# ## Age

# %%
print(f"Anzahl der Werte: {len(raw_data['age'])}")
print(f"Einzigartige Werte: {raw_data['age'].nunique()}")
print(f"Fehlende Werte: {raw_data['age'].isnull().sum()}")
print(f"Mittelwert: {raw_data['age'].mean():.2f}")
print(f"Median: {raw_data['age'].median():.2f}")
print(f"Minimum: {raw_data['age'].min()}")
print(f"Maximum: {raw_data['age'].max()}")
print(f"25% Quartil: {raw_data['age'].quantile(0.25):.2f}")
print(f"75% Quartil: {raw_data['age'].quantile(0.75):.2f}")

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

sns.histplot(raw_data['age'], bins=50, kde=True, ax=ax1)
ax1.set_title(f'Histogramm von age')
ax1.set_xlabel('age')
ax1.set_ylabel('Häufigkeit')

sns.boxplot(y=raw_data['age'], ax=ax2)
ax2.set_title(f'Boxplot von age')
ax2.set_ylabel('age')
# Out:
# Anzahl der Werte: 45211
# Einzigartige Werte: 77
# Fehlende Werte: 0
# Mittelwert: 40.94
# Median: 39.00
# Minimum: 18
# Maximum: 95
# 25% Quartil: 33.00
# 75% Quartil: 48.00
# Text(0, 0.5, 'age')

# %% [markdown]
# ## Job

# %%
print(f"Anzahl der Werte: {len(raw_data['job'])}")
print(f"Einzigartige Werte: {raw_data['job'].nunique()}")
print(f"Fehlende Werte: {raw_data['job'].isnull().sum()}")

value_counts = raw_data['job'].value_counts()
percentages = raw_data['job'].value_counts(normalize=True) * 100

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

sns.barplot(x=value_counts.index, y=value_counts.values, ax=ax1, palette='viridis')
ax1.set_title(f'Barplot von job')
ax1.set_xlabel('job')
ax1.set_ylabel('Häufigkeit')
ax1.tick_params(axis='x', rotation=45)

ax2.pie(percentages, labels=percentages.index, autopct='%1.1f%%', startangle=180)
ax2.set_title(f'Pie Chart von job')
ax2.axis('equal')

plt.tight_layout()
plt.show()
# Out:
# Anzahl der Werte: 45211
# Einzigartige Werte: 12
# Fehlende Werte: 0

# %% [markdown]
# ## Marital

# %%
print(f"Anzahl der Werte: {len(raw_data['marital'])}")
print(f"Einzigartige Werte: {raw_data['marital'].nunique()}")
print(f"Fehlende Werte: {raw_data['marital'].isnull().sum()}")

value_counts = raw_data['marital'].value_counts()
percentages = raw_data['marital'].value_counts(normalize=True) * 100

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

sns.barplot(x=value_counts.index, y=value_counts.values, ax=ax1, palette='viridis')
ax1.set_title(f'Barplot von marital')
ax1.set_xlabel('marital')
ax1.set_ylabel('Häufigkeit')
ax1.tick_params(axis='x', rotation=45)

ax2.pie(percentages, labels=percentages.index, autopct='%1.1f%%', startangle=180)
ax2.set_title(f'Pie Chart von marital')
ax2.axis('equal')

plt.tight_layout()
plt.show()
# Out:
# Anzahl der Werte: 45211
# Einzigartige Werte: 3
# Fehlende Werte: 0

# %% [markdown]
# ## Education

# %%
print(f"Anzahl der Werte: {len(raw_data['education'])}")
print(f"Einzigartige Werte: {raw_data['education'].nunique()}")
print(f"Fehlende Werte: {raw_data['education'].isnull().sum()}")

value_counts = raw_data['education'].value_counts()
percentages = raw_data['education'].value_counts(normalize=True) * 100

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

sns.barplot(x=value_counts.index, y=value_counts.values, ax=ax1, palette='viridis')
ax1.set_title(f'Barplot von education')
ax1.set_xlabel('education')
ax1.set_ylabel('Häufigkeit')
ax1.tick_params(axis='x', rotation=45)

ax2.pie(percentages, labels=percentages.index, autopct='%1.1f%%', startangle=180)
ax2.set_title(f'Pie Chart von education')
ax2.axis('equal')

plt.tight_layout()
plt.show()
# Out:
# Anzahl der Werte: 45211
# Einzigartige Werte: 4
# Fehlende Werte: 0

# %% [markdown]
# ## Default

# %%
print(f"Anzahl der Werte: {len(raw_data['default'])}")
print(f"Einzigartige Werte: {raw_data['default'].nunique()}")
print(f"Fehlende Werte: {raw_data['default'].isnull().sum()}")

value_counts = raw_data['default'].value_counts()
percentages = raw_data['default'].value_counts(normalize=True) * 100

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

sns.barplot(x=value_counts.index, y=value_counts.values, ax=ax1, palette='viridis')
ax1.set_title(f'Barplot von default')
ax1.set_xlabel('default')
ax1.set_ylabel('Häufigkeit')
ax1.tick_params(axis='x', rotation=45)

ax2.pie(percentages, labels=percentages.index, autopct='%1.1f%%', startangle=180)
ax2.set_title(f'Pie Chart von default')
ax2.axis('equal')

plt.tight_layout()
plt.show()
# Out:
# Anzahl der Werte: 45211
# Einzigartige Werte: 2
# Fehlende Werte: 0

# %% [markdown]
# ## Balance

# %%
print(f"Anzahl der Werte: {len(raw_data['balance'])}")
print(f"Einzigartige Werte: {raw_data['balance'].nunique()}")
print(f"Fehlende Werte: {raw_data['balance'].isnull().sum()}")
print(f"Mittelwert: {raw_data['balance'].mean():.2f}")
print(f"Median: {raw_data['balance'].median():.2f}")
print(f"Minimum: {raw_data['balance'].min()}")
print(f"Maximum: {raw_data['balance'].max()}")
print(f"25% Quartil: {raw_data['balance'].quantile(0.25):.2f}")
print(f"75% Quartil: {raw_data['balance'].quantile(0.75):.2f}")

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

sns.histplot(raw_data['balance'], bins=50, kde=True, ax=ax1)
ax1.set_title(f'Histogramm von balance')
ax1.set_xlabel('balance')
ax1.set_ylabel('Häufigkeit')

sns.boxplot(y=raw_data['balance'], ax=ax2)
ax2.set_title(f'Boxplot von balance')
ax2.set_ylabel('balance')
# Out:
# Anzahl der Werte: 45211
# Einzigartige Werte: 7168
# Fehlende Werte: 0
# Mittelwert: 1362.27
# Median: 448.00
# Minimum: -8019
# Maximum: 102127
# 25% Quartil: 72.00
# 75% Quartil: 1428.00
# Text(0, 0.5, 'balance')

# %% [markdown]
# ## Housing

# %%
print(f"Anzahl der Werte: {len(raw_data['housing'])}")
print(f"Einzigartige Werte: {raw_data['housing'].nunique()}")
print(f"Fehlende Werte: {raw_data['housing'].isnull().sum()}")

value_counts = raw_data['housing'].value_counts()
percentages = raw_data['housing'].value_counts(normalize=True) * 100

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

sns.barplot(x=value_counts.index, y=value_counts.values, ax=ax1, palette='viridis')
ax1.set_title(f'Barplot von housing')
ax1.set_xlabel('housing')
ax1.set_ylabel('Häufigkeit')
ax1.tick_params(axis='x', rotation=45)

ax2.pie(percentages, labels=percentages.index, autopct='%1.1f%%', startangle=180)
ax2.set_title(f'Pie Chart von housing')
ax2.axis('equal')

plt.tight_layout()
plt.show()
# Out:
# Anzahl der Werte: 45211
# Einzigartige Werte: 2
# Fehlende Werte: 0

# %% [markdown]
# ## Loan

# %%
print(f"Anzahl der Werte: {len(raw_data['loan'])}")
print(f"Einzigartige Werte: {raw_data['loan'].nunique()}")
print(f"Fehlende Werte: {raw_data['loan'].isnull().sum()}")

value_counts = raw_data['loan'].value_counts()
percentages = raw_data['loan'].value_counts(normalize=True) * 100

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

sns.barplot(x=value_counts.index, y=value_counts.values, ax=ax1, palette='viridis')
ax1.set_title(f'Barplot von loan')
ax1.set_xlabel('loan')
ax1.set_ylabel('Häufigkeit')
ax1.tick_params(axis='x', rotation=45)

ax2.pie(percentages, labels=percentages.index, autopct='%1.1f%%', startangle=180)
ax2.set_title(f'Pie Chart von loan')
ax2.axis('equal')

plt.tight_layout()
plt.show()
# Out:
# Anzahl der Werte: 45211
# Einzigartige Werte: 2
# Fehlende Werte: 0

# %% [markdown]
# ## Contact

# %%
print(f"Anzahl der Werte: {len(raw_data['contact'])}")
print(f"Einzigartige Werte: {raw_data['contact'].nunique()}")
print(f"Fehlende Werte: {raw_data['contact'].isnull().sum()}")

value_counts = raw_data['contact'].value_counts()
percentages = raw_data['contact'].value_counts(normalize=True) * 100

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

sns.barplot(x=value_counts.index, y=value_counts.values, ax=ax1, palette='viridis')
ax1.set_title(f'Barplot von contact')
ax1.set_xlabel('contact')
ax1.set_ylabel('Häufigkeit')
ax1.tick_params(axis='x', rotation=45)

ax2.pie(percentages, labels=percentages.index, autopct='%1.1f%%', startangle=180)
ax2.set_title(f'Pie Chart von contact')
ax2.axis('equal')

plt.tight_layout()
plt.show()
# Out:
# Anzahl der Werte: 45211
# Einzigartige Werte: 3
# Fehlende Werte: 0

# %% [markdown]
# ## Day

# %%
print(f"Anzahl der Werte: {len(raw_data['day'])}")
print(f"Einzigartige Werte: {raw_data['day'].nunique()}")
print(f"Fehlende Werte: {raw_data['day'].isnull().sum()}")
print(f"Mittelwert: {raw_data['day'].mean():.2f}")
print(f"Median: {raw_data['day'].median():.2f}")
print(f"Minimum: {raw_data['day'].min()}")
print(f"Maximum: {raw_data['day'].max()}")
print(f"25% Quartil: {raw_data['day'].quantile(0.25):.2f}")
print(f"75% Quartil: {raw_data['day'].quantile(0.75):.2f}")

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

sns.histplot(raw_data['day'], bins=50, kde=True, ax=ax1)
ax1.set_title(f'Histogramm von day')
ax1.set_xlabel('day')
ax1.set_ylabel('Häufigkeit')

sns.boxplot(y=raw_data['day'], ax=ax2)
ax2.set_title(f'Boxplot von day')
ax2.set_ylabel('day')
# Out:
# Anzahl der Werte: 45211
# Einzigartige Werte: 31
# Fehlende Werte: 0
# Mittelwert: 15.81
# Median: 16.00
# Minimum: 1
# Maximum: 31
# 25% Quartil: 8.00
# 75% Quartil: 21.00
# Text(0, 0.5, 'day')

# %% [markdown]
# ## Month

# %%
print(f"Anzahl der Werte: {len(raw_data['month'])}")
print(f"Einzigartige Werte: {raw_data['month'].nunique()}")
print(f"Fehlende Werte: {raw_data['month'].isnull().sum()}")

value_counts = raw_data['month'].value_counts()
percentages = raw_data['month'].value_counts(normalize=True) * 100

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

sns.barplot(x=value_counts.index, y=value_counts.values, ax=ax1, palette='viridis')
ax1.set_title(f'Barplot von month')
ax1.set_xlabel('month')
ax1.set_ylabel('Häufigkeit')
ax1.tick_params(axis='x', rotation=45)

ax2.pie(percentages, labels=percentages.index, autopct='%1.1f%%', startangle=180)
ax2.set_title(f'Pie Chart von month')
ax2.axis('equal')

plt.tight_layout()
plt.show()
# Out:
# Anzahl der Werte: 45211
# Einzigartige Werte: 12
# Fehlende Werte: 0

# %% [markdown]
# ## Duration

# %%
print(f"Anzahl der Werte: {len(raw_data['duration'])}")
print(f"Einzigartige Werte: {raw_data['duration'].nunique()}")
print(f"Fehlende Werte: {raw_data['duration'].isnull().sum()}")
print(f"Mittelwert: {raw_data['duration'].mean():.2f}")
print(f"Median: {raw_data['duration'].median():.2f}")
print(f"Minimum: {raw_data['duration'].min()}")
print(f"Maximum: {raw_data['duration'].max()}")
print(f"25% Quartil: {raw_data['duration'].quantile(0.25):.2f}")
print(f"75% Quartil: {raw_data['duration'].quantile(0.75):.2f}")

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

sns.histplot(raw_data['duration'], bins=50, kde=True, ax=ax1)
ax1.set_title(f'Histogramm von duration')
ax1.set_xlabel('duration')
ax1.set_ylabel('Häufigkeit')

sns.boxplot(y=raw_data['duration'], ax=ax2)
ax2.set_title(f'Boxplot von duration')
ax2.set_ylabel('duration')
# Out:
# Anzahl der Werte: 45211
# Einzigartige Werte: 1573
# Fehlende Werte: 0
# Mittelwert: 258.16
# Median: 180.00
# Minimum: 0
# Maximum: 4918
# 25% Quartil: 103.00
# 75% Quartil: 319.00
# Text(0, 0.5, 'duration')

# %% [markdown]
# ## Campaign

# %%
print(f"Anzahl der Werte: {len(raw_data['campaign'])}")
print(f"Einzigartige Werte: {raw_data['campaign'].nunique()}")
print(f"Fehlende Werte: {raw_data['campaign'].isnull().sum()}")
print(f"Mittelwert: {raw_data['campaign'].mean():.2f}")
print(f"Median: {raw_data['campaign'].median():.2f}")
print(f"Minimum: {raw_data['campaign'].min()}")
print(f"Maximum: {raw_data['campaign'].max()}")
print(f"25% Quartil: {raw_data['campaign'].quantile(0.25):.2f}")
print(f"75% Quartil: {raw_data['campaign'].quantile(0.75):.2f}")

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

sns.histplot(raw_data['campaign'], bins=50, kde=True, ax=ax1)
ax1.set_title(f'Histogramm von campaign')
ax1.set_xlabel('campaign')
ax1.set_ylabel('Häufigkeit')

sns.boxplot(y=raw_data['campaign'], ax=ax2)
ax2.set_title(f'Boxplot von campaign')
ax2.set_ylabel('campaign')
# Out:
# Anzahl der Werte: 45211
# Einzigartige Werte: 48
# Fehlende Werte: 0
# Mittelwert: 2.76
# Median: 2.00
# Minimum: 1
# Maximum: 63
# 25% Quartil: 1.00
# 75% Quartil: 3.00
# Text(0, 0.5, 'campaign')

# %% [markdown]
# ## Pdays

# %%
print(f"Anzahl der Werte: {len(raw_data['pdays'])}")
print(f"Einzigartige Werte: {raw_data['pdays'].nunique()}")
print(f"Fehlende Werte: {raw_data['pdays'].isnull().sum()}")
print(f"Mittelwert: {raw_data['pdays'].mean():.2f}")
print(f"Median: {raw_data['pdays'].median():.2f}")
print(f"Minimum: {raw_data['pdays'].min()}")
print(f"Maximum: {raw_data['pdays'].max()}")
print(f"25% Quartil: {raw_data['pdays'].quantile(0.25):.2f}")
print(f"75% Quartil: {raw_data['pdays'].quantile(0.75):.2f}")

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

sns.histplot(raw_data['pdays'], bins=50, kde=True, ax=ax1)
ax1.set_title(f'Histogramm von pdays')
ax1.set_xlabel('pdays')
ax1.set_ylabel('Häufigkeit')

sns.boxplot(y=raw_data['pdays'], ax=ax2)
ax2.set_title(f'Boxplot von pdays')
ax2.set_ylabel('pdays')
# Out:
# Anzahl der Werte: 45211
# Einzigartige Werte: 559
# Fehlende Werte: 0
# Mittelwert: 40.20
# Median: -1.00
# Minimum: -1
# Maximum: 871
# 25% Quartil: -1.00
# 75% Quartil: -1.00
# Text(0, 0.5, 'pdays')

# %% [markdown]
# ## Previous

# %%
print(f"Anzahl der Werte: {len(raw_data['previous'])}")
print(f"Einzigartige Werte: {raw_data['previous'].nunique()}")
print(f"Fehlende Werte: {raw_data['previous'].isnull().sum()}")
print(f"Mittelwert: {raw_data['previous'].mean():.2f}")
print(f"Median: {raw_data['previous'].median():.2f}")
print(f"Minimum: {raw_data['previous'].min()}")
print(f"Maximum: {raw_data['previous'].max()}")
print(f"25% Quartil: {raw_data['previous'].quantile(0.25):.2f}")
print(f"75% Quartil: {raw_data['previous'].quantile(0.75):.2f}")

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

sns.histplot(raw_data['previous'], bins=50, kde=True, ax=ax1)
ax1.set_title(f'Histogramm von previous')
ax1.set_xlabel('previous')
ax1.set_ylabel('Häufigkeit')

sns.boxplot(y=raw_data['previous'], ax=ax2)
ax2.set_title(f'Boxplot von previous')
ax2.set_ylabel('previous')
# Out:
# Anzahl der Werte: 45211
# Einzigartige Werte: 41
# Fehlende Werte: 0
# Mittelwert: 0.58
# Median: 0.00
# Minimum: 0
# Maximum: 275
# 25% Quartil: 0.00
# 75% Quartil: 0.00
# Text(0, 0.5, 'previous')

# %% [markdown]
# ## Poutcome

# %%
print(f"Anzahl der Werte: {len(raw_data['poutcome'])}")
print(f"Einzigartige Werte: {raw_data['poutcome'].nunique()}")
print(f"Fehlende Werte: {raw_data['poutcome'].isnull().sum()}")

value_counts = raw_data['poutcome'].value_counts()
percentages = raw_data['poutcome'].value_counts(normalize=True) * 100

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

sns.barplot(x=value_counts.index, y=value_counts.values, ax=ax1, palette='viridis')
ax1.set_title(f'Barplot von poutcome')
ax1.set_xlabel('poutcome')
ax1.set_ylabel('Häufigkeit')
ax1.tick_params(axis='x', rotation=45)

ax2.pie(percentages, labels=percentages.index, autopct='%1.1f%%', startangle=180)
ax2.set_title(f'Pie Chart von poutcome')
ax2.axis('equal')

plt.tight_layout()
plt.show()
# Out:
# Anzahl der Werte: 45211
# Einzigartige Werte: 4
# Fehlende Werte: 0

# %% [markdown]
# ## Y

# %%
print(f"Anzahl der Werte: {len(raw_data['y'])}")
print(f"Einzigartige Werte: {raw_data['y'].nunique()}")
print(f"Fehlende Werte: {raw_data['y'].isnull().sum()}")

value_counts = raw_data['y'].value_counts()
percentages = raw_data['y'].value_counts(normalize=True) * 100

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

sns.barplot(x=value_counts.index, y=value_counts.values, ax=ax1, palette='viridis')
ax1.set_title(f'Barplot von y')
ax1.set_xlabel('y')
ax1.set_ylabel('Häufigkeit')
ax1.tick_params(axis='x', rotation=45)

ax2.pie(percentages, labels=percentages.index, autopct='%1.1f%%', startangle=180)
ax2.set_title(f'Pie Chart von y')
ax2.axis('equal')

plt.tight_layout()
plt.show()
# Out:
# Anzahl der Werte: 45211
# Einzigartige Werte: 2
# Fehlende Werte: 0

# %% [markdown]
# # Variablentranformation
# Umwandeln der Variablen in eine für ML geeignete Form. Handling von Ausreißern und Missing Values

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline

data_transformed = raw_data.copy()

# %% [markdown]
# ## Age
# Missing: keine
# Außreißer: Ja durch wenige Alte Personen, sind aber korrekt deswegen behalten
#
# Umformung: Binning in Altersgruppen, One-Hot Encoding

# %%
data_transformed['age_group'] = pd.cut(data_transformed['age'], bins=[0, 25, 35, 50, 65, 100], labels=['young', 'young_adult', 'adult', 'middle_aged', 'senior'])
data_transformed = pd.get_dummies(data_transformed, columns=['age_group'], prefix='age_group', drop_first=True)
data_transformed = data_transformed.drop('age', axis=1)

# %% [markdown]
# ## Job
# Missing: 288 Unknown
# Ausreißer: keine
#
# Umformung:
# Unknown als eigene Kategorie behalten, Hot-One Encoding

# %%
data_transformed = pd.get_dummies(data_transformed, columns=['job'], prefix='job', drop_first=True)

# %% [markdown]
# ## Marital
# Missing: keine
# Ausreißer: keine
#
# Umformung: keine Änderungen nötig, Hot-One Encoding

# %%
data_transformed = pd.get_dummies(data_transformed, columns=['marital'], prefix='marital', drop_first=True)

# %% [markdown]
# ## Education
# Missing: 1857 Missing
# Ausreißer: keine
#
# Umformung: Unknown als eigene Kategorie behalten, Hot-One encoding

# %%
data_transformed = pd.get_dummies(data_transformed, columns=['education'], prefix='education', drop_first=True)

# %% [markdown]
# ## Default
# Missing: keine
# Ausreißer: keine
#
# Umformung: kann unverändert genutzt werden, Hot-One encoding

# %%
data_transformed = pd.get_dummies(data_transformed, columns=['default'], prefix='default', drop_first=True)

# %% [markdown]
# ## Balance
# Missing: keine
# Ausreißer: starke Ausreißer nach oben
# Problem: negative werte
#
# Umformung:

# %%
data_transformed['balance_log'] = np.log1p(data_transformed['balance'] - data_transformed['balance'].min() + 1)
data_transformed = data_transformed.drop('balance', axis=1)

# %% [markdown]
# ## Housing
# Missing: keine
# Ausreißer: keine
#
# Umformung: kann unverändert genutzt werden, Hot-One encoding

# %%
data_transformed = pd.get_dummies(data_transformed, columns=['housing'], prefix='housing', drop_first=True)

# %% [markdown]
# ## Loan
# Missing: keine
# Ausreißer: keine
#
# Umformung: kann unverändert genutzt werden, Hot-One encoding

# %%
data_transformed = pd.get_dummies(data_transformed, columns=['loan'], prefix='loan', drop_first=True)

# %% [markdown]
# ## Contact
# Missing: 13.020 Missing
# Ausreißer: keine
#
# Umformung: Unknown als eigene Kategorie behalten, Hot-One encoding

# %%
data_transformed = pd.get_dummies(data_transformed, columns=['contact'], prefix='contact', drop_first=True)

# %% [markdown]
# ## Day
# Missing: keine
# Ausreißer: keine
#
# Umformung: unverändert, numerischer wert

# %% [markdown]
# ## Month
# Missing: keine
# Ausreißer: keine
#
# Umformung: enumerate, umwandeln in numerischen wert

# %%
month_order = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']
data_transformed['month_encoded'] = data_transformed['month'].map({month: i for i, month in enumerate(month_order)})
data_transformed = data_transformed.drop('month', axis=1)

# %% [markdown]
# ## Duration
# Wert entsteht erst im Anschluss, Variable wird vollständig entfernt

# %%
data_transformed = data_transformed.drop('duration', axis=1)

# %% [markdown]
# ## Campaign
# Missing: keine
# Ausreißer: Ja
#
# Umformung: Log um hohe nicht zu sehr herrausstechen zu lassen

# %%
data_transformed['campaign_log'] = np.log1p(data_transformed['campaign'])
data_transformed = data_transformed.drop('campaign', axis=1)

# %% [markdown]
# ## Aufteilen des Datensatztes
# Der Datensatzt unterteilt sich in Einträge bei denen der Kunde in früheren Kampanien bereits kontaktiert wurde und in Kunden die zum ersten mal kontaktiert werden.
#
# Beide Teile müssen getrennt und einzelnd betrachtet werden!

# %%
data_firsts_final = data_transformed[data_transformed['pdays'] == -1]
data_previous_final = data_transformed[data_transformed['pdays'] != -1]

data_firsts_final = data_firsts_final.drop('pdays', axis=1)
data_firsts_final = data_firsts_final.drop('previous', axis=1)
data_firsts_final = data_firsts_final.drop('poutcome', axis=1)

# %% [markdown]
# ## Y
# Missing: keine
# Ausreißer: keine
#
# Umformung: unverändert, Hot-one encoding

# %%
data_firsts_final = pd.get_dummies(data_firsts_final, columns=['y'], prefix='y', drop_first=True)
data_previous_final = pd.get_dummies(data_previous_final, columns=['y'], prefix='y', drop_first=True)
data_firsts_final = data_firsts_final.rename(columns={'y_yes': 'y'})
data_previous_final = data_previous_final.rename(columns={'y_yes': 'y'})

# %% [markdown]
# ## Pdays
# Missing: keine
# Ausreißer: keine
#
# Umformung: behalten als Numerischer Wert

# %%
print(f"Anzahl der Werte: {len(data_previous_final['pdays'])}")
print(f"Einzigartige Werte: {data_previous_final['pdays'].nunique()}")
print(f"Fehlende Werte: {data_previous_final['pdays'].isnull().sum()}")
print(f"Mittelwert: {data_previous_final['pdays'].mean():.2f}")
print(f"Median: {data_previous_final['pdays'].median():.2f}")
print(f"Minimum: {data_previous_final['pdays'].min()}")
print(f"Maximum: {data_previous_final['pdays'].max()}")
print(f"25% Quartil: {data_previous_final['pdays'].quantile(0.25):.2f}")
print(f"75% Quartil: {data_previous_final['pdays'].quantile(0.75):.2f}")

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

sns.histplot(data_previous_final['pdays'], bins=50, kde=True, ax=ax1)
ax1.set_title(f'Histogramm von pdays')
ax1.set_xlabel('pdays')
ax1.set_ylabel('Häufigkeit')

sns.boxplot(y=data_previous_final['pdays'], ax=ax2)
ax2.set_title(f'Boxplot von pdays')
ax2.set_ylabel('pdays')
# Out:
# Anzahl der Werte: 8257
# Einzigartige Werte: 558
# Fehlende Werte: 0
# Mittelwert: 224.58
# Median: 194.00
# Minimum: 1
# Maximum: 871
# 25% Quartil: 133.00
# 75% Quartil: 327.00
# Text(0, 0.5, 'pdays')

# %% [markdown]
# ## Previous
# Missing: keine
# Ausreißer: 1 extremwert, möglicher Fehler
#
# Umformung: Ausreißer wird entfernt, log

# %%
print(f"Anzahl der Werte: {len(data_previous_final['previous'])}")
print(f"Einzigartige Werte: {data_previous_final['previous'].nunique()}")
print(f"Fehlende Werte: {data_previous_final['previous'].isnull().sum()}")
print(f"Mittelwert: {data_previous_final['previous'].mean():.2f}")
print(f"Median: {data_previous_final['previous'].median():.2f}")
print(f"Minimum: {data_previous_final['previous'].min()}")
print(f"Maximum: {data_previous_final['previous'].max()}")
print(f"25% Quartil: {data_previous_final['previous'].quantile(0.25):.2f}")
print(f"75% Quartil: {data_previous_final['previous'].quantile(0.75):.2f}")

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

sns.histplot(data_previous_final['previous'], bins=50, kde=True, ax=ax1)
ax1.set_title(f'Histogramm von previous')
ax1.set_xlabel('previous')
ax1.set_ylabel('Häufigkeit')

sns.boxplot(y=data_previous_final['previous'], ax=ax2)
ax2.set_title(f'Boxplot von previous')
ax2.set_ylabel('previous')

data_previous_final = data_previous_final[data_previous_final['previous'] < 100]
data_previous_final['previous'] = np.log1p(data_previous_final['previous'])
# Out:
# Anzahl der Werte: 8257
# Einzigartige Werte: 40
# Fehlende Werte: 0
# Mittelwert: 3.18
# Median: 2.00
# Minimum: 1
# Maximum: 275
# 25% Quartil: 1.00
# 75% Quartil: 4.00

# %% [markdown]
# ## Poutcome
# Missing: ja 5 unknown
# Ausreißer: keine
#
# Umformung: unknown entfernen da 5 kein großer verlust ,Hot-One encoding

# %%
print(f"Anzahl der Werte: {len(data_previous_final['poutcome'])}")
print(f"Einzigartige Werte: {data_previous_final['poutcome'].nunique()}")
print(f"Fehlende Werte: {data_previous_final['poutcome'].isnull().sum()}")

value_counts = data_previous_final['poutcome'].value_counts().head(3)
percentages = data_previous_final['poutcome'].value_counts(normalize=True).head(3) * 100

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

sns.barplot(x=value_counts.index, y=value_counts.values, ax=ax1, palette='viridis')
ax1.set_title(f'Barplot von poutcome')
ax1.set_xlabel('poutcome')
ax1.set_ylabel('Häufigkeit')
ax1.tick_params(axis='x', rotation=45)

ax2.pie(percentages, labels=percentages.index, autopct='%1.1f%%', startangle=180)
ax2.set_title(f'Pie Chart von poutcome')
ax2.axis('equal')

plt.tight_layout()
plt.show()

data_previous_final = data_previous_final[data_previous_final['poutcome'] != 'unknown']
data_previous_final = pd.get_dummies(data_previous_final, columns=['poutcome'], prefix='poutcome', drop_first=True)
# Out:
# Anzahl der Werte: 8256
# Einzigartige Werte: 4
# Fehlende Werte: 0

# %%
print(data_firsts_final.columns.tolist())
print(data_previous_final.columns.tolist())
data_firsts_final.to_csv('data_firsts_final.csv', index=False)
data_previous_final.to_csv('data_previous_final.csv', index=False)
# Out:
# ['day', 'age_group_young_adult', 'age_group_adult', 'age_group_middle_aged', 'age_group_senior', 'job_blue-collar', 'job_entrepreneur', 'job_housemaid', 'job_management', 'job_retired', 'job_self-employed', 'job_services', 'job_student', 'job_technician', 'job_unemployed', 'job_unknown', 'marital_married', 'marital_single', 'education_secondary', 'education_tertiary', 'education_unknown', 'default_yes', 'balance_log', 'housing_yes', 'loan_yes', 'contact_telephone', 'contact_unknown', 'month_encoded', 'campaign_log', 'y']
# ...
